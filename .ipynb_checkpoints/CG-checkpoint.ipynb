# %%
import cv2

# Open the .mov file
video = cv2.VideoCapture('4_sabre.MOV')

# Check if the video is successfully opened
if not video.isOpened():
    print("Error opening video file")

# Initialize variables
frame_count = 0

# Read and save frames until the end of the video
while video.isOpened():
    # Read the current frame
    ret, frame = video.read()

    # Check if frame is successfully read
    if not ret:
        break

    # Save the frame as an image file
    frame_filename = f"sframe_{frame_count}.jpg"
    cv2.imwrite(frame_filename, frame)

    # Increment frame count
    frame_count += 1

    # Display the current frame (optional)
    cv2.imshow('Frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video object and close any open windows
video.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 16
#      13 # Read and save frames until the end of the video
#      14 while video.isOpened():
#      15     # Read the current frame
# ---> 16     ret, frame = video.read()
#      18     # Check if frame is successfully read
#      19     if not ret:
#
# KeyboardInterrupt:

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
print('started') 
im = cv2.imread('bestimage.jpg')
value_collector = np.zeros(im.shape)
list_of_frames = []
for frame_number in range (0,100):
    im_temp = cv2.imread('sframe_'+str(frame_number)+'.jpg')
    list_of_frames += [im_temp]
print('out of loop')
images = np.stack(list_of_frames, axis=0)
median_image = np.median(images, axis=0).astype(np.uint8) #long one
plt.imshow(median_image)
plt.show() 
print('finished')
# Out:
# started
# out of loop
# finished
